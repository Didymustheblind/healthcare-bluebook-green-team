# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
with_backslashes = pd.read_excel(r'c:\users\erinm\documents\healthcare-bluebook-green-team\data\BACKSLASH_TEST_FILE.xlsx')
with_backslashes.head()
# Out:
#    ZIP/CODE  CBSA/FIELD  RES_RATIO  BUS_RATIO  OTH_RATIO/ERIN  TOT_RATIO
# 0       501       35620        0.0        1.0             0.0        1.0
# 1       601       38660        1.0        1.0             1.0        1.0
# 2       602       10380        1.0        1.0             1.0        1.0
# 3       603       10380        1.0        1.0             1.0        1.0
# 4       604       10380        1.0        1.0             1.0        1.0

# %%
with_backslashes.columns.str.strip().str.replace('/','_')
# Out:
# Index(['ZIP_CODE', 'CBSA_FIELD', 'RES_RATIO', 'BUS_RATIO', 'OTH_RATIO_ERIN',
#        'TOT_RATIO'],
#       dtype='object')

# %%
with_backslashes.head()
# Out:
#    ZIP/CODE  CBSA/FIELD  RES_RATIO  BUS_RATIO  OTH_RATIO/ERIN  TOT_RATIO
# 0       501       35620        0.0        1.0             0.0        1.0
# 1       601       38660        1.0        1.0             1.0        1.0
# 2       602       10380        1.0        1.0             1.0        1.0
# 3       603       10380        1.0        1.0             1.0        1.0
# 4       604       10380        1.0        1.0             1.0        1.0

# %%
with_backslashes.columns = with_backslashes.columns.str.strip().str.lower().str.replace('/', '?').str.replace('_', '$')

# %%
with_backslashes.columns
# Out:
# Index(['zip?code', 'cbsa?field', 'res$ratio', 'bus$ratio', 'oth$ratio?erin',
#        'tot$ratio'],
#       dtype='object')

# %%
with_backslashes.head()
# Out:
#    zip?code  cbsa?field  res$ratio  bus$ratio  oth$ratio?erin  tot$ratio
# 0       501       35620        0.0        1.0             0.0        1.0
# 1       601       38660        1.0        1.0             1.0        1.0
# 2       602       10380        1.0        1.0             1.0        1.0
# 3       603       10380        1.0        1.0             1.0        1.0
# 4       604       10380        1.0        1.0             1.0        1.0

# %%
test2 = pd.read_excel(r'c:\users\erinm\documents\healthcare-bluebook-green-team\data\BACKSLASH_TEST_FILE_2.xlsx')
test2.head()
# Out:
#    ZIP/CODE  CBSA\FIELD  RES_RATIO/GO  BUS_RATIO\yes  OTH_RATIO/ERIN  \
# 0       501       35620           0.0            1.0             0.0
# 1       601       38660           1.0            1.0             1.0
# 2       602       10380           1.0            1.0             1.0
# 3       603       10380           1.0            1.0             1.0
# 4       604       10380           1.0            1.0             1.0
#
#    TOT_RATIO
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0

# %%
test2.columns = test2.columns.str.strip().str.replace('\\', '/')

#.str.replace('\','_')

# %%
test2.head()
# Out:
#    ZIP/CODE  CBSA/FIELD  RES_RATIO/GO  BUS_RATIO/yes  OTH_RATIO/ERIN  \
# 0       501       35620           0.0            1.0             0.0
# 1       601       38660           1.0            1.0             1.0
# 2       602       10380           1.0            1.0             1.0
# 3       603       10380           1.0            1.0             1.0
# 4       604       10380           1.0            1.0             1.0
#
#    TOT_RATIO
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
