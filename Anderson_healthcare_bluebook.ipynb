# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset_1 = pd.read_csv('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.tsv', sep='\t')
dataset_1.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000126                                   ENKESHAFI
# 2                    1003000126                                   ENKESHAFI
# 3                    1003000126                                   ENKESHAFI
# 4                    1003000126                                   ENKESHAFI
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                    ARDALAN                            NaN
# 2                    ARDALAN                            NaN
# 3                    ARDALAN                            NaN
# 4                    ARDALAN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# ...

# %%
dataset_1.shape
# Out:
# (9847443, 26)

# %%
#agg_table=pd.read_csv('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2017.tsv', sep='\t')
#agg_table.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000134                                      CIBULL
# 2                    1003000142                                      KHALIL
# 3                    1003000407                                     GIRARDI
# 4                    1003000423                                     VELOTTA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                     THOMAS                              L
# 2                     RASHID                            NaN
# 3                      DAVID                              J
# 4                   JENNIFER                              A
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# ...

# %%
drpay_agg_combo=pd.merge(dr_payments_df, agg_table, on=('National Provider Identifier'), how='inner')
drpay_agg_combo.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider_x  \
# 0                    1003000126                                     ENKESHAFI
# 1                    1003000126                                     ENKESHAFI
# 2                    1003000126                                     ENKESHAFI
# 3                    1003000126                                     ENKESHAFI
# 4                    1003000126                                     ENKESHAFI
#
#   First Name of the Provider_x Middle Initial of the Provider_x  \
# 0                      ARDALAN                              NaN
# 1                      ARDALAN                              NaN
# 2                      ARDALAN                              NaN
# 3                      ARDALAN                              NaN
# 4                      ARDALAN                              NaN
#
#   Credentials of the Provider_x Gender of the Provider_x  \
# ...

# %%
drpay_agg_combo.shape
# Out:
# (9847443, 96)

# %%
outpatient_charges_df = pd.read_csv('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017.csv')
outpatient_charges_df.head()
outpatient_charges_df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-04f1a633992a> in <module>
# ----> 1 outpatient_charges_df = pd.read_csv('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017.csv')
#       2 outpatient_charges_df.head()
#       3 outpatient_charges_df.shape
#
# ...

# %%
outpatient_charges_df = pd.read_csv('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017.tsv', sep='\t')
outpatient_charges_df.shape
# Out:
# (61779, 16)

# %%
outpatient_charges_df.head()
# Out:
#    Provider_ID                     Provider_Name Provider_Street_Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider_City Provider_State  Provider_Zip_Code Provider_HRR   APC  \
# 0        Dothan             AL              36301  AL - Dothan  5072
# 1        Dothan             AL              36301  AL - Dothan  5073
# 2        Dothan             AL              36301  AL - Dothan  5091
# 3        Dothan             AL              36301  AL - Dothan  5092
# 4        Dothan             AL              36301  AL - Dothan  5112
#
#                                             APC_Desc  Beneficiaries  \
# ...

# %%
outpatient_charges_df.tail()
# Out:
#        Provider_ID                             Provider_Name  \
# 61774       670122  Houston Methodist The Woodlands Hospital
# 61775       670122  Houston Methodist The Woodlands Hospital
# 61776       670122  Houston Methodist The Woodlands Hospital
# 61777       670122  Houston Methodist The Woodlands Hospital
# 61778       670122  Houston Methodist The Woodlands Hospital
#
#          Provider_Street_Address  Provider_City Provider_State  \
# 61774  17201 Interstate 45 South  The Woodlands             TX
# 61775  17201 Interstate 45 South  The Woodlands             TX
# 61776  17201 Interstate 45 South  The Woodlands             TX
# 61777  17201 Interstate 45 South  The Woodlands             TX
# 61778  17201 Interstate 45 South  The Woodlands             TX
#
#        Provider_Zip_Code  Provider_HRR   APC  \
# 61774              77385  TX - Houston  5361
# 61775              77385  TX - Houston  5373
# 61776              77385  TX - Houston  5375
# ...

# %%
add_b_init = pd.read_excel('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/2020_january_web_addendum_b.12312019.xlsx')
add_b_init.head()
# Out:
#    Unnamed: 0 Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020  \
# 0         NaN  CPT codes and descriptions only are copyright ...
# 1  HCPCS Code                                   Short Descriptor
# 2       00100                              Anesth salivary gland
# 3       00102                         Anesth repair of cleft lip
# 4       00103                              Anesth blepharoplasty
#
#   Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0        NaN        NaN              NaN            NaN
# 1         SI       APC   Relative Weight  Payment Rate
# 2          N        NaN              NaN            NaN
# 3          N        NaN              NaN            NaN
# 4          N        NaN              NaN            NaN
#
#                        Unnamed: 6                     Unnamed: 7  \
# 0                             NaN                            NaN
# 1  National Unadjusted Copayment   Minimum Unadjusted Copayment
# ...

# %%
add_b = pd.read_excel('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/2020_january_web_addendum_b.12312019.xlsx',usecols=[0,1,3], skiprows=2)
add_b.head()
# Out:
#   HCPCS Code            Short Descriptor  APC
# 0      00100       Anesth salivary gland   NaN
# 1      00102  Anesth repair of cleft lip   NaN
# 2      00103       Anesth blepharoplasty   NaN
# 3      00104         Anesth electroshock   NaN
# 4      00120          Anesth ear surgery   NaN

# %%
#add_b = pd.read_excel('c:/users/erinm/Documents/healthcare-bluebook-green-team/data/2020_january_web_addendum_b.12312019.xlsx', header=0,  skiprows=2, nrows= 20, use_cols = "A:D")
#add_b

# %%
zip_cbsa = pd.read_excel('c:/users/erinm/documents/healthcare-bluebook-green-team/data/ZIP_CBSA_032020.xlsx')
zip_cbsa.shape
# Out:
# (47415, 6)

# %%
zip_cbsa.head()
# Out:
#    ZIP   CBSA  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0  501  35620        0.0        1.0        0.0        1.0
# 1  601  38660        1.0        1.0        1.0        1.0
# 2  602  10380        1.0        1.0        1.0        1.0
# 3  603  10380        1.0        1.0        1.0        1.0
# 4  604  10380        1.0        1.0        1.0        1.0

# %%
provider_plus_cptcross = pd.merge(dr_payments_df, add_b, on=('HCPCS Code'), how='inner')
provider_plus_cptcross.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1003000126                                   ENKESHAFI
# 1                    1003000407                                     GIRARDI
# 2                    1003006586                                     MAREEDU
# 3                    1003007824                                       SOWAH
# 4                    1003008590                                CHIRUMAMILLA
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                    ARDALAN                            NaN
# 1                      DAVID                              J
# 2                    JYOTSNA                            NaN
# 3                    LEONARD                              A
# 4                      RADHA                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                        M.D.                      M
# ...

# %%
provider_plus_cptcross.shape
# Out:
# (9502517, 28)

# %%
provider_plus_cptcross.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount', 'Short Descriptor', 'APC '],
#       dtype='object')

# %%
no_null=provider_plus_cptcross[provider_plus_cptcross['APC '].notnull()]
no_null.head()
# Out:
#         National Provider Identifier  \
# 720335                    1003000126
# 720336                    1003002841
# 720337                    1003003609
# 720338                    1003004771
# 720339                    1003005729
#
#        Last Name/Organization Name of the Provider First Name of the Provider  \
# 720335                                   ENKESHAFI                    ARDALAN
# 720336                                   CHOUDHARY                      SAHER
# 720337                                PAKKIVENKATA                        UMA
# 720338                                      RIGGLE                       ERIN
# 720339                                     WALNOHA                       WADE
#
#        Middle Initial of the Provider Credentials of the Provider  \
# 720335                            NaN                        M.D.
# 720336                              K                        M.D.
# 720337                              B                        M.D.
# ...

# %%
musculoskeletal_only =no_null[no_null['APC '].isin([5112, 5113, 5114, 5115, 5116])]
#musculoskeletal_only =no_null[no_null['APC '].isin([5302])]

musculoskeletal_only.shape
# Out:
# (60478, 28)

# %%
musculoskeletal_only.head()
# Out:
#          National Provider Identifier  \
# 3795609                    1003000738
# 3795610                    1003015843
# 3795611                    1003084849
# 3795612                    1003103474
# 3795613                    1003110792
#
#          Last Name/Organization Name of the Provider  \
# 3795609                                      ZUMWALT
# 3795610  NORTHBAY PHYSICIAN'S SURGERY CENTER, L.L.C.
# 3795611                                      ZANAROS
# 3795612               NEW ALBANY SURGERY CENTER, LLC
# 3795613              CREVE COEUR SURGERY CENTER, LLC
#
#         First Name of the Provider Middle Initial of the Provider  \
# 3795609                   JULIETTE                              A
# 3795610                        NaN                            NaN
# 3795611                     GEORGE                              S
# 3795612                        NaN                            NaN
# 3795613                        NaN                            NaN
#
# ...

# %%
musculoskeletal_ento =musculoskeletal_only[musculoskeletal_only['Entity Type of the Provider'].isin(['O'])]
musculoskeletal_ento.shape
# Out:
# (7348, 28)

# %%
musculoskeletal_ento.head()
# Out:
#          National Provider Identifier  \
# 3795610                    1003015843
# 3795612                    1003103474
# 3795613                    1003110792
# 3795618                    1003860917
# 3795619                    1003870825
#
#          Last Name/Organization Name of the Provider  \
# 3795610  NORTHBAY PHYSICIAN'S SURGERY CENTER, L.L.C.
# 3795612               NEW ALBANY SURGERY CENTER, LLC
# 3795613              CREVE COEUR SURGERY CENTER, LLC
# 3795618             SURGERY CENTER OF PINEHURST, LLC
# 3795619                 PINELLAS SURGERY CENTER, LTD
#
#         First Name of the Provider Middle Initial of the Provider  \
# 3795610                        NaN                            NaN
# 3795612                        NaN                            NaN
# 3795613                        NaN                            NaN
# 3795618                        NaN                            NaN
# 3795619                        NaN                            NaN
#
# ...

# %%
#musculoskeletal_ento_asc =musculoskeletal_ento[musculoskeletal_ento['Provider Type'].isin(['Ambulatory Surgical Center'])]
#musculoskeletal_ento_asc.head()

# %%
#musculoskeletal_ento_asc.shape

# %%
musculoskeletal_ento_asc_poso =musculoskeletal_ento[musculoskeletal_ento['Place of Service'].isin(['F'])]
musculoskeletal_ento_asc_poso.shape
# Out:
# (7348, 28)

# %%
musculoskeletal_ento_asc_poso.head()
# Out:
#          National Provider Identifier  \
# 3795610                    1003015843
# 3795612                    1003103474
# 3795613                    1003110792
# 3795618                    1003860917
# 3795619                    1003870825
#
#          Last Name/Organization Name of the Provider  \
# 3795610  NORTHBAY PHYSICIAN'S SURGERY CENTER, L.L.C.
# 3795612               NEW ALBANY SURGERY CENTER, LLC
# 3795613              CREVE COEUR SURGERY CENTER, LLC
# 3795618             SURGERY CENTER OF PINEHURST, LLC
# 3795619                 PINELLAS SURGERY CENTER, LTD
#
#         First Name of the Provider Middle Initial of the Provider  \
# 3795610                        NaN                            NaN
# 3795612                        NaN                            NaN
# 3795613                        NaN                            NaN
# 3795618                        NaN                            NaN
# 3795619                        NaN                            NaN
#
# ...

# %%
musculoskeletal_ento_asc_poso['HCPCS Description'].value_counts()
# Out:
# Incision of tendon covering                                           791
# Removal of one knee cartilage using an endoscope                      762
# Removal of both knee cartilages using an endoscope                    646
# Repair of shoulder rotator cuff using an endoscope                    626
# Correction of toe joint deformity                                     561
#                                                                      ...
# Repair of disrupted collateral ligament of ankle                        1
# Removal of growth of tendon covering or joint capsule of toes           1
# Repair of ruptured Achilles tendon, open or through skin procedure      1
# Repair of finger tendon                                                 1
# Incision and exploration of wrist joint                                 1
# Name: HCPCS Description, Length: 174, dtype: int64
